# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: requests>=2.31 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (6.33.2)
# Requirement already satisfied: websockets>=13.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: cffi>=1.12.0 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from statsmodels) (2.3.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from statsmodels) (2.3.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sumitsharma/Desktop/Quant/Hello_Quant.py/quant_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 1. Data Retrieval (Using Indian Stocks - append .NS for NSE)
tickers = ['SBIN.NS', 'BANKBARODA.NS']
data = yf.download(tickers, start="2023-01-01", end="2025-01-01" , auto_adjust=True)

# 1.5 Correlation Check (Pair Pre-Filter)

prices = data['Close']
rolling_corr = prices['SBIN.NS'].rolling(60).corr(prices['BANKBARODA.NS'])

avg_corr = rolling_corr.mean()
print(f"Average Rolling Correlation (60-day): {avg_corr:.2f}")

# 2. Calculate Hedge Ratio using OLS
Y = data['Close']['SBIN.NS']
X = data['Close']['BANKBARODA.NS']

X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
hedge_ratio = model.params['BANKBARODA.NS']

# 3. Generate Spread and Z-Score

data['spread'] = (
    data['Close']['SBIN.NS']
    - hedge_ratio * data['Close']['BANKBARODA.NS']
)

data['zscore'] = (
    (data['spread'] - data['spread'].rolling(window=20).mean())
    / data['spread'].rolling(window=20).std()
)

# 3.1 Cointegration Check (ADF Test on Spread)
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(data['spread'].dropna())

print(f"ADF Statistic: {adf_result[0]:.4f}")
print(f"p-value: {adf_result[1]:.4f}")
print("Critical Values:")
for key, value in adf_result[4].items():
    print(f"   {key}: {value:.4f}")


# 4. Trading Signals
data['position'] = 0
data.loc[data['zscore'] > 2, 'position'] = -1  # Short the spread
data.loc[data['zscore'] < -2, 'position'] = 1   # Long the spread
data['position'] = data['position'].ffill().fillna(0) # Carry position until exit logic

# 5. Calculate Returns
# Strategy return = position * (return of SBIN − hedge_ratio * return of BANKBARODA)

data['returns'] = (
    data['position'].shift(1)
    * (
        data['Close']['SBIN.NS'].pct_change()
        - hedge_ratio * data['Close']['BANKBARODA.NS'].pct_change()
    )
)

data['cumulative_returns'] = (1 + data['returns'].fillna(0)).cumprod()


# 6. Plot Results
plt.figure(figsize=(12, 6))
plt.plot(data['cumulative_returns'], label='Pairs Strategy', color='green')
plt.title('Backtest Results: SBIN vs BANKBARODA')
plt.xlabel('Date')
plt.ylabel('Cumulative Growth')
plt.legend()
plt.show()

print(f"Final Return: {(data['cumulative_returns'].iloc[-1] - 1) * 100:.2f}%")
# Out:
# [*********************100%***********************]  2 of 2 completed
# Average Rolling Correlation (60-day): 0.73
# ADF Statistic: -1.9165
# p-value: 0.3243
# Critical Values:
#    1%: -3.4438
#    5%: -2.8675
#    10%: -2.5699
# Final Return: 7.48%
